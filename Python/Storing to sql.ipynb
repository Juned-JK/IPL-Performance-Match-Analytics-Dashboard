# %%
import pandas as pd

# %%
df = pd.read_csv(
    r"C:\Users\juned\Videos\data analytics\end to end projects\IPL DATASET\Data\IPL.csv",
    low_memory=False
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278954 entries, 0 to 278953
# Data columns (total 62 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   match_id           278954 non-null  int64
#  1   date               278954 non-null  object
#  2   match_type         278954 non-null  object
#  3   event_name         278954 non-null  object
#  4   innings            278954 non-null  int64
#  5   batting_team       278954 non-null  object
#  6   bowling_team       278954 non-null  object
#  7   over               278954 non-null  int64
#  8   ball               278954 non-null  int64
#  9   ball_no            278954 non-null  float64
#  10  batter             278954 non-null  object
#  11  bat_pos            278954 non-null  int64
#  12  runs_batter        278954 non-null  int64
#  13  balls_faced        278954 non-null  int64
#  14  bowler             278954 non-null  object
# ...

# %%
df.describe()
# Out:
#            match_id        innings           over           ball  \
# count  2.789540e+05  278954.000000  278954.000000  278954.000000
# mean   9.526833e+05       1.482567       9.196065       3.489181
# std    3.871456e+05       0.499697       5.675448       1.708286
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483560e+05       1.000000       4.000000       2.000000
# 50%    1.082610e+06       1.000000       9.000000       3.000000
# 75%    1.304068e+06       2.000000      14.000000       5.000000
# max    1.529267e+06       2.000000      19.000000       7.000000
#
#              ball_no        bat_pos    runs_batter    balls_faced  \
# count  278954.000000  278954.000000  278954.000000  278954.000000
# mean        9.544983       3.619185       1.281319       0.966995
# std         5.676840       2.171429       1.655404       0.178651
# min         0.100000       1.000000       0.000000       0.000000
# ...

# %%
df.nunique()
# Out:
# match_id            1169
# date                 892
# match_type             1
# event_name             1
# innings                2
#                     ...
# batter_balls          74
# bowler_wicket          2
# batting_partners    5186
# next_batter          676
# striker_out            2
# Length: 62, dtype: int64

# %%
df['batting_team'] = df['batting_team'].str.replace('Delhi Daredevils','Delhi Capitals')
df['bowling_team'] = df['bowling_team'].str.replace('Delhi Daredevils','Delhi Capitals')
df['batting_team'] = df['batting_team'].str.replace('Kings XI Punjab','Punjab Kings')
df['bowling_team'] = df['bowling_team'].str.replace('Kings XI Punjab','Punjab Kings')
df['batting_team'] = df['batting_team'].str.replace('Rising Pune Supergiant','Rising Pune Supergiants')
df['bowling_team'] = df['bowling_team'].str.replace('Rising Pune Supergiant','Rising Pune Supergiants')
df['batting_team'] = df['batting_team'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')
df['bowling_team'] = df['bowling_team'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')

# %%
team_map = {
    'Delhi Daredevils': 'Delhi Capitals',
    'Kings XI Punjab': 'Punjab Kings',
    'Rising Pune Supergiant': 'Rising Pune Supergiants',
    'Rising Pune Supergiantss' : 'Rising Pune Supergiants',
    'Royal Challengers Bangalore': 'Royal Challengers Bengaluru'
}

df['batting_team'] = df['batting_team'].replace(team_map)
df['bowling_team'] = df['bowling_team'].replace(team_map)
df['match_won_by'] = df['match_won_by'].replace(team_map)
df['toss_winner'] = df['toss_winner'].replace(team_map)
# we will change venue/city names too by doing this i changed them in excel

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:Khan#222@localhost/cricketdata")

# %%
df.to_sql(
    name = 'ipl',
    con = engine,
    if_exists = 'replace',
    index = False
)
print("done")
# Out:
# done
